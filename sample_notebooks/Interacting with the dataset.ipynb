# %% [markdown]
# # CZI Software Mentions Dataset - Interacting with the Dataset
#
#
# This notebook offers examples of **interacting** with the <b>CZI Software Mentions dataset </b><br>
# The <b>CZI Software Mentions dataset </b> is a large dataset of software mentions mined from the literature.
#
# **Dataset Overview**: Plain-text software mentions are extracted with a trained [SciBERT](#references_scibert)model from several sources: the NIH PubMed Central collection and from papers provided by various publishers to the Chan Zuckerberg Initiative. The dataset provides sources, context and metadata, and, for a number of mentions, the disambiguated software entities and links. Full description of the dataset, methodology, algorihms and evaluation used to create the dataset can be found in our preprint, [A large dataset of software mentions in the biomedical literature](https://arxiv.org/abs/2209.00693) and on our [Github page](https://github.com/chanzuckerberg/software-mentions).
#
#
# **The notebook is structured and offers the following information and examples, as follows:**
#
# 1. [Interacting with dataset](#dataset_interaction)
#     1. [Description of the dataset](#dataset_interaction_description)
#     2. [raw files](#dataset_interaction_raw)
#         1. Example: [Query the dataset for a particular plain-text software mention](#dataset_interaction_raw_query_scipy)
#         2. Example: [Retrieve texts in which a particular plain-text software mention appears](#dataset_interaction_raw_samples_scipy)
#         3. Example: [Retrieve the most frequent plain-text software mentions in the corpus](#dataset_interaction_raw_most_frequent_mentions)
#         4. Motivation: [Understanding curation labels](#dataset_interaction_raw_curation_labels)
#     3. [disambiguated files](#dataset_interaction_disambiguated)
#         1. Motivation: [Why do we need disambiguation? Examples showcasing string variation](#dataset_interaction_disambiguated_motivation)
#         2. Example: [Query the dataset for a particular software, including all string variations](#dataset_interaction_disambiguated_dataset_query)
#         3. Example: [Examples of disambiguated software terms](#dataset_interaction_disambiguated_examples)
#         4. Example: [Retrieve the most frequent software mentions based on disambiguated dataset](#dataset_interaction_disambiguated_most_frequent_mentions)
#     4. [linked files](#dataset_interaction_linked)
#         1. Example: [Query the linked data](#dataset_interaction_linked_query)
#         2. Example: [Exploration of metadata fields](#dataset_interaction_linked_metadata_fields)
# 2. Example: [Query the dataset for a particular software, including all string variations, and links](#dataset_interaction_linked_query) (Example for **scikit-learn**)
#
# There is a different notebook, [CZI Software Mentions Dataset - Sample Use Cases](#link_here), that offers sample use cases for the dataset.
#
# **The full list of resources we have available for the dataset is**:
# 1. [Preprint: A large dataset of software mentions in the biomedical literature](https://arxiv.org/abs/2209.00693)
# 2. [Github Repository](https://github.com/chanzuckerberg/software-mentions)
# 3. [Dataset](https://datadryad.org/stash/dataset/doi:10.5061/dryad.6wwpzgn2c?)
# 4. [Interacting with the Dataset](https://github.com/chanzuckerberg/software-mentions/blob/main/sample_notebooks/Interacting%20with%20the%20dataset.ipynb) - Jupyter Notebook
# 5. [Sample Use Cases](https://github.com/chanzuckerberg/software-mentions/blob/main/sample_notebooks/Sample%20Use%20Cases.ipynb) - Jupyter Notebook
#
# For questions, please contact aistrate@chanzuckerberg.com

# %%
import pandas as pd
import numpy as np
pd.set_option('max_colwidth', 1000)

# %% [markdown]
# <a id='dataset_interaction'></a>
#
# ## Interacting with the dataset
# We offer a brief overview of the dataset below. For a full description, including detailed information about the available files and fields, and how they were obtained, please consult the dataset [README.md](https://datadryad.org/stash/dataset/doi:10.5061/dryad.6wwpzgn2c?) file, or the Appendix section of our [preprint](https://arxiv.org/abs/2209.00693)

# %% [markdown]
# <a id='dataset_interaction_description'></a>
# ### Dataset Description

# %% [markdown]
# The notebook assumes that the dataset files are stored in a folder `data` that sits as the same level as the `sample_notebooks` directory. The assumed directory structure is the following:
#
# - `sample_notebooks`
# -  `data`
#     - `raw`
#         - comm_raw.tsv.gz
#         - non_comm_raw.tsv.gz
#         - publishers_collection_raw.tsv.gz
#     - `disambiguated`
#         - comm_disambiguated.tsv.gz
#     - `linked`
#         - metadata.tsv.gz
#
# Description of the folders is as follows:
#  - [`raw`](#dataset_interaction_raw) : raw, plain-text software mentions, as extracted by the NER model
#  - [`disambiguated`](#dataset_interaction_disambiguated): disambiguated software mentions, after disambiguation
#  - [`linked`](#dataset_interaction_linked) :  linked software mentions
#
# Note that for the folder `raw`, you don't have to have all of the `comm`, `non_comm`, and `publishers_collection` files. You can shoose as many as you would like to interact with. The description of these files is:
#
# - `comm` : contains data extracted from the PMC OA **commercial** subset
# - `non_comm` : contains data extracted from the PMC OA **non-commercial** subset
# subset)
# - `publishers_collection` : contains data extracted from the **CZI Publishers Collection**
#
# In the following sections, we will show how to interact with the different modalities of the dataset and touch on the motivation and different use cases each modality carries.

# %%
ROOT_DATA_DIR = '../data/'

# %% [markdown]
# <a id='dataset_interaction_raw'></a>
# ### raw files
#
# The **raw** files contain raw, plain-text software mentions, as extracted by the NER model from each of the collections. As mentioned in the [Intro of this section](#dataset_interaction), there are three possible files to interact with:
#  - comm_raw.tsv.gz
#  - non_comm_raw.tsv.gz
#  - publishers_collection_raw.tsv.gz
#
# These files are quite large (~1GB zipped) and are stored as GZIP files.
# If you are using **pandas**, we recommend the following approach. <br>
# Note that we offer an example of reading only the first 5000000 rows of the dataset, to speed up the computation. <br>
# For full analysis of the dataset, you should take `nrows=num_rows_to_read` out and run:

# %%
raw_df = pd.read_csv(ROOT_DATA_DIR + 'raw/comm_raw.tsv.gz', sep = '\\t', engine = 'python', compression = 'gzip')

# %%
# num_rows_to_read = 5000000
# raw_df = pd.read_csv(ROOT_DATA_DIR + 'raw/comm_raw.tsv.gz', sep = '\\t', engine = 'python', compression = 'gzip', nrows = num_rows_to_read)

# %% [markdown]
# <color value = red>**Warning**</color>: It may take a while for the command to finish running (up to an hour), especially for the `comm` and `publishers_collection`. <br>
# If you would like to quickly interact with the dataset, we recommend opening the `non_comm` file first, as it's the smallest one. <br><br>
# Once the file is read, we can start exploring it! Let's look at a few samples:

# %%
raw_df.sample(3)
# Out:
#          license                                 location    pmcid  \
# 7610808     comm         comm/Dis_Markers/PMC7369658.nxml  7369658
# 11554458    comm             comm/Sci_Rep/PMC5830603.nxml  5830603
# 8486300     comm  comm/Front_Hum_Neurosci/PMC4267277.nxml  4267277
#
#                 pmid                         doi  pubdate  \
# 7610808   32733620.0        10.1155/2020/8817652     2020
# 11554458  29491348.0  10.1038/s41598-018-22015-3     2018
# 8486300   25566017.0    10.3389/fnhum.2014.00975     2014
#
#                                                   source  number  \
# 7610808   2.1. Data Acquisition and Integrative Analysis       3
# 11554458                            Computational Method      11
# 8486300                                     SAM ANALYSIS       8
#
#                                                                                                                                                                                                            text  \
# 7610808                                                          Based on R software and packages [21], we analyzed the above data to obtain differentially methylated genes and differentially expressed genes
# 11554458                                                   Modified ClayFF potential parameters were developed by Kerisit et al.; these predict contact between the silicate structure and water on the surface
# 8486300   Given that SPM2 uses standard brains from the MNI, the MNI coordinates were converted to Talairach coordinates using nonlinear transformation (Lancaster et al., 2000) in the mri3dX software package
#
#          software version        ID curation_label
# 7610808         R     NaN       SM3       software
# 11554458   ClayFF     NaN   SM22146    not_curated
# 8486300    mri3dX     NaN  SM261667    not_curated

# %% [markdown]
# And the fields we have available:

# %%
raw_df.columns
# Out:
# Index(['license', 'location', 'pmcid', 'pmid', 'doi', 'pubdate', 'source',
#        'number', 'text', 'software', 'version', 'ID', 'curation_label'],
#       dtype='object')

# %% [markdown]
# Some field definitions that will be relevant for our work in this notebook:
# - **software** : the software mention extracted by the NER algorithm from **text**
# - **version** : software version as extracted by the NER algorithm (note that not all mentions will have this)
# - **text** : text that **software** is being extracted from
# - **curation_label** : label assigned to software mention by our curators
#
# All of the other fields are related to metadata of the paper the mention is extracted from.
# For a full definition of all of the fields, please take a look at the [Dataset README.md](link) file in our [Github repo](https://github.com/chanzuckerberg/software-mentions).

# %% [markdown]
# Now, let's look at a few examples of interacting with the dataset:
# <a id='dataset_interaction_raw_query_scipy'></a>
#
# #### 1.Query the dataset
# Example of querying the dataset for the plain-text software mention 'scipy'

# %%
scipy_mentions_df = raw_df[raw_df['software'] == 'scipy']

# %%
scipy_mentions_df.head(3)
# Out:
#      license                             location    pmcid        pmid  \
# 8488    comm        comm/ACS_Nano/PMC7905882.nxml  7905882  33556239.0
# 9849    comm  comm/ACS_Synth_Biol/PMC8486170.nxml  8486170  33449631.0
# 9853    comm  comm/ACS_Synth_Biol/PMC8486170.nxml  8486170  33449631.0
#
#                             doi  pubdate               source  number  \
# 8488    10.1021/acsnano.0c10632     2021     Cluster Analysis      40
# 9849  10.1021/acssynbio.0c00318     2021          fig_caption       5
# 9853  10.1021/acssynbio.0c00318     2021  Computational Model      12
#
#                                                                                                                         text  \
# 8488                 The 83.4% confidence interval for the mean was calculated using the implementation in the scipy package
# 9849                                             Wavelength was computed using scipy FFT and peak finding standard libraries
# 9853  Signal analysis (FFT) and visualization were carried out using the scipy and Matplotlib.pyplot libraries, respectively
#
#      software version      ID curation_label
# 8488    scipy     NaN  SM3076       software
# 9849    scipy     NaN  SM3076       software
# 9853    scipy     NaN  SM3076       software

# %% [markdown]
# <a id='dataset_interaction_raw_samples_scipy'></a>
# #### 2. Samples of texts in which the mention 'scipy'  appears

# %%
scipy_mentions_df[['pmid', 'source', 'text', 'software']].sample(10)
# Out:
#                 pmid  \
# 12525610  32340276.0
# 13884611  30688649.0
# 7320937   33208883.0
# 13936236  33289631.0
# 3865516   28495919.0
# 8325546   30344485.0
# 9786263   31653678.0
# 3379536   31011536.0
# 3171323   32958603.0
# 6128102   25781329.0
#
#                                                                     source  \
# 12525610                                                               NaN
# 13884611                                  Consensus and unsigned consensus
# 7320937                                                 Surrogate modeling
# 13936236                                          DeepLabCut-Live! package
# 3865516                                                Statistical methods
# 8325546                              Statistical analysis of distributions
# 9786263   Simulating a 10-locus system with neutral and selected variants:
# 3379536                                                       Architecture
# 3171323                         Connection specificity modules and network
# 6128102                                                        Programming
#
#                                                                                                                                                                                                                                                                           text  \
# 12525610                                                                                                                                                                                                               Function welch from the scipy library was used for that
# 13884611                            For visual clarity, these values were interpolated by a third-degree univariate spline calculated using the python package scipy.interpolate.InterpolatedUnivariateSpline (this technique is guaranteed to intercept the measured values).
# 7320937                                                                                                 We use the scipy.interpolate.griddata method from the Python Scipy package to implement 2D barycentric linear interpolation and treat each PCA component independently
# 13936236                                                                                                                              It utilizes TensorFlow (Abadi et al., 2016), numpy (Svd et al., 2011), scipy (Virtanen et al., 2020), OpenCV (Bradski, 2000), and others
# 3865516   Since the data were not normally distributed, a two‐sided non‐parametrical Mann–Whitney test was applied, implemented in python using the function stats.mannwhitneyu in scipy, with Bonferroni correction on the minor fraction for each gene on the two cell types
# 8325546                                                                                                                                            Kurtosis and skewness were tested using the scipy functions, stats.kurtosistest and stats.skewtest (https://docs.scipy.org)
# 9786263                                                                                                                                       For Gaussian DES, the mean γ is zero, as above, and is found by numerical optimization using scipy (Jones ) to give the desired
# 3379536                                                                                                                                                                                                        numpy, scipy, and scikit-learn) and continuous integration (e.g
# 3171323                                                                                                                                                           The Pairwise distance between regulons is calculated by “scipy.spatial.distance.pdist” with Euclidean metric
# 6128102                                                                                                                                 Data acquisition and analysis were done using the Python programming language with the pandas, numpy, scipy, and matplotlib extensions
#
#          software
# 12525610    scipy
# 13884611    scipy
# 7320937     scipy
# 13936236    scipy
# 3865516     scipy
# 8325546     scipy
# 9786263     scipy
# 3379536     scipy
# 3171323     scipy
# 6128102     scipy

# %% [markdown]
# <a id='dataset_interaction_raw_most_frequent_mentions'></a>
# #### 3. Retrieve the most frequent software mentions in the corpus
# Note that here, we define *frequency* by number of unique papers a software appears in
#
# **Warning**: this command also takes a long time! Feel free to skip it if you're not interested in this section.

# %%
raw_df_aggregated = raw_df.groupby('software').nunique().sort_values(by = 'pmid', ascending = False)
raw_df_aggregated[:30]
# Out:
#                  license  location   pmcid    pmid     doi  pubdate  source  \
# software
# SPSS                   1    286647  286647  285279  279566       22   31053
# R                      1    192460  192460  191817  191636       21  101864
# GraphPad Prism         1    119661  119661  119357  118576       19   27484
# ImageJ                 1     94715   94715   94428   93950       19   76479
# Excel                  1     80247   80247   79826   79447       24   33460
# GraphPad               1     75614   75614   75438   74900       19   14637
# SAS                    1     75133   75133   74919   74596       23   15059
# BLAST                  1     54981   54981   54870   54660       24   54508
# Stata                  1     46462   46462   46279   46175       20    7807
# MATLAB                 1     46532   46532   46265   46417       21   39037
# SPSS Statistics        1     38049   38049   37875   37858       14    5225
# STATA                  1     34310   34310   34149   34037       19    5365
# Prism                  1     32221   32221   32155   31936       20    9567
# Matlab                 1     31191   31191   30967   31091       20   24623
# Image J                1     30905   30905   30835   30465       19   22244
# FlowJo                 1     29058   29058   29008   28726       18   16923
# MEGA                   1     24099   24099   24059   23997       19   15776
# COVID                  1     20990   20990   20163   20912        2   12618
# SHELXL97               1     19266   19266   19265   19266       15     105
# Cytoscape              1     18147   18147   18072   18020       18   19499
# SHELXS97               1     17501   17501   17499   17500       15      72
# Ensembl                1     16951   16951   16915   16835       19   18842
# Google Scholar         1     15503   15503   15330   15232       17    5218
# -                      1     15310   15310   15189   15246       25    9767
# Google                 1     14812   14812   14604   14669       21    8730
# Adobe Photoshop        1     14393   14393   14370   14216       21    8913
# ClustalW               1     14248   14248   14231   14159       18   10506
# Python                 1     14108   14107   14001   14095       18   11032
# PACE                   1     13781   13781   13760   13778       16     110
# Statistica             1     13287   13287   13227   13192       18    3054
#
#                  number    text  version  ID  curation_label
# software
# SPSS                691  291953      836   1               1
# R                   662  299463     1042   1               1
# GraphPad Prism      295  129161      409   1               1
# ImageJ              349  159854      753   1               1
# Excel               444   96334      299   1               1
# GraphPad            240   76420      134   1               1
# SAS                 318   88060      292   1               1
# BLAST               287  100939      122   1               1
# Stata               355   52525      383   1               1
# MATLAB              375   77802      595   1               1
# SPSS Statistics     195   36057      208   1               1
# STATA               287   37892      301   1               1
# Prism               231   35683      272   1               1
# Matlab              326   48311      464   1               1
# Image J             195   43781      337   1               1
# FlowJo              209   33137      260   1               1
# MEGA                183   35867      335   1               1
# COVID               497   49213        4   1               1
# SHELXL97             54    7164        0   1               1
# Cytoscape           225   39448      198   1               1
# SHELXS97             46    6009        0   1               1
# Ensembl             239   37432      156   1               1
# Google Scholar      276   22939        4   1               1
# -                   324   18698      259   1               1
# Google              302   27081       10   1               1
# Adobe Photoshop     187   16016      288   1               1
# ClustalW            182   19473       48   1               1
# Python              312   19917      194   1               1
# PACE                705     362        1   1               1
# Statistica          152   13543      155   1               1

# %% [markdown]
# <a id='dataset_interaction_raw_curation_labels'></a>
# #### 4. Understanding curation labels

# %% [markdown]
# Now, we may notice that in the most frequent software_mentions retrieved above, there are some obvious false positives picked up by the NER model, such as **'COVID'**, **'COVID-19'** or **'Google'**. This is why we engaged an expert team of biomedical curators to sanity-check the top 10k plain-text software mentions extracted by the NER model from the `comm` dataset. We offer more details about the methodology and guidelines in our [preprint](link), as well as on our [Github Repo](https://github.com/chanzuckerberg/software-mentions). The datasets contain a field ```curation_label``` that tells us the label our curation team assigned to a software mention, or if it was not curated at all.

# %% [markdown]
# Let's explore these **curation_label** a bit. First, let's see what values are available

# %%
raw_df['curation_label'].unique()
# Out:
# array(['not_curated', 'unclear', 'software', 'not_software'], dtype=object)

# %% [markdown]
# Now, let's create the **mention2curation_label** mapping to map from a mention to its curation label

# %%
mentions_curation_label_df = raw_df[['software', 'curation_label']].drop_duplicates()
mentions = mentions_curation_label_df['software'].values
curation_labels = mentions_curation_label_df['curation_label'].values
mention2curation_label = {m : c for m, c in zip(mentions, curation_labels)}

# %% [markdown]
# Let's look at curation labels of the top most frequent mentions obtained above:

# %%
raw_df_aggregated = raw_df_aggregated.reset_index()
raw_df_aggregated['curation_label'] = raw_df_aggregated['software'].apply(lambda x: mention2curation_label[x])
raw_df_aggregated[:30]
# Out:
#     index         software  license  location   pmcid    pmid     doi  \
# 0       0             SPSS        1    286647  286647  285279  279566
# 1       1                R        1    192460  192460  191817  191636
# 2       2   GraphPad Prism        1    119661  119661  119357  118576
# 3       3           ImageJ        1     94715   94715   94428   93950
# 4       4            Excel        1     80247   80247   79826   79447
# 5       5         GraphPad        1     75614   75614   75438   74900
# 6       6              SAS        1     75133   75133   74919   74596
# 7       7            BLAST        1     54981   54981   54870   54660
# 8       8            Stata        1     46462   46462   46279   46175
# 9       9           MATLAB        1     46532   46532   46265   46417
# 10     10  SPSS Statistics        1     38049   38049   37875   37858
# 11     11            STATA        1     34310   34310   34149   34037
# 12     12            Prism        1     32221   32221   32155   31936
# 13     13           Matlab        1     31191   31191   30967   31091
# 14     14          Image J        1     30905   30905   30835   30465
# 15     15           FlowJo        1     29058   29058   29008   28726
# 16     16             MEGA        1     24099   24099   24059   23997
# 17     17            COVID        1     20990   20990   20163   20912
# 18     18         SHELXL97        1     19266   19266   19265   19266
# 19     19        Cytoscape        1     18147   18147   18072   18020
# 20     20         SHELXS97        1     17501   17501   17499   17500
# 21     21          Ensembl        1     16951   16951   16915   16835
# 22     22   Google Scholar        1     15503   15503   15330   15232
# 23     23                -        1     15310   15310   15189   15246
# 24     24           Google        1     14812   14812   14604   14669
# 25     25  Adobe Photoshop        1     14393   14393   14370   14216
# 26     26         ClustalW        1     14248   14248   14231   14159
# 27     27           Python        1     14108   14107   14001   14095
# 28     28             PACE        1     13781   13781   13760   13778
# 29     29       Statistica        1     13287   13287   13227   13192
#
#     pubdate  source  number    text  version  ID curation_label
# 0        22   31053     691  291953      836   1       software
# 1        21  101864     662  299463     1042   1       software
# 2        19   27484     295  129161      409   1       software
# 3        19   76479     349  159854      753   1       software
# 4        24   33460     444   96334      299   1       software
# 5        19   14637     240   76420      134   1       software
# 6        23   15059     318   88060      292   1        unclear
# 7        24   54508     287  100939      122   1       software
# 8        20    7807     355   52525      383   1       software
# 9        21   39037     375   77802      595   1       software
# 10       14    5225     195   36057      208   1       software
# 11       19    5365     287   37892      301   1       software
# 12       20    9567     231   35683      272   1       software
# 13       20   24623     326   48311      464   1       software
# 14       19   22244     195   43781      337   1       software
# 15       18   16923     209   33137      260   1       software
# 16       19   15776     183   35867      335   1       software
# 17        2   12618     497   49213        4   1   not_software
# 18       15     105      54    7164        0   1       software
# 19       18   19499     225   39448      198   1       software
# 20       15      72      46    6009        0   1       software
# 21       19   18842     239   37432      156   1       software
# 22       17    5218     276   22939        4   1   not_software
# 23       25    9767     324   18698      259   1   not_software
# 24       21    8730     302   27081       10   1   not_software
# 25       21    8913     187   16016      288   1       software
# 26       18   10506     182   19473       48   1       software
# 27       18   11032     312   19917      194   1       software
# 28       16     110     705     362        1   1        unclear
# 29       18    3054     152   13543      155   1       software

# %% [markdown]
# We can see that the mentions `COVID`, `COVID-19`, `Google Scholar`, as well as `Google` have been correctly marked by our curators as **not_software**. <br>
# We can now segment the dataset based on the curation_labels:

# %%
not_software_raw = raw_df[raw_df['curation_label'] == 'not_software']
unclear_raw = raw_df[raw_df['curation_label'] == 'unclear']
not_curated_raw = raw_df[raw_df['curation_label'] == 'not_curated']
software_raw = raw_df[raw_df['curation_label'] == 'software']

# %% [markdown]
# Let's look at some more examples of mentions that have been marked by our curators as **not_software** and the context in which they appear:

# %%
not_software_raw.sample(10)[['pmid', 'text', 'software']]
# Out:
#                 pmid  \
# 7059298   32341447.0
# 9145575   33574758.0
# 13577999  34574584.0
# 3921529   33917796.0
# 5934161   32017786.0
# 1146748   15784138.0
# 9731133   33322033.0
# 853912    20096121.0
# 4927004   34529649.0
# 8070115   26339471.0
#
#                                                                                                                                                                                                                                             text  \
# 7059298                                                                                                                                                                              Data based on 100000 simulations for MOMP and minimal MOMP.
# 9145575                                                                                                                       RASFF is used in the European Union to help obtain the minimally required safety and quality of feed and food (i.e
# 13577999  For the scopes of the present study, it was fitted with the Easy Alarm YouTube application and included audio files presenting the verbal reminders for the start of the activities and the instructions concerning the activity steps
# 3921529                                                                                                                                                                  Result of the potential DDIs at each documentation level of Micromedex.
# 5934161                                                                                                           PLOS ONE does not copyedit accepted manuscripts, so the language in submitted articles must be clear, correct, and unambiguous
# 1146748                                                                                                                   TIGR's in-house non-redundant protein database (NRAA) was searched and aligned to the Arabidopsis BACs using this tool
# 9731133                                                                                                                               Nextflow and the containerization software can be run on Linux, Mac OS, and Windows supported through WSL2
# 853912                                                                                                                                                                                     Analysis of the gene atlas data using PCA and NeatMap
# 4927004                                                                One study had explored the use of Google Trends data as a predictor [24], and the other used a set of meteorological information for generating outbreak predictions [25]
# 8070115                                                                                                                                                    AGRIS: providing access to agricultural research data exploiting open data on the web
#
#                software
# 7059298            MOMP
# 9145575           RASFF
# 13577999        YouTube
# 3921529      Micromedex
# 5934161             ONE
# 1146748            TIGR
# 9731133         Windows
# 853912              PCA
# 4927004   Google Trends
# 8070115           AGRIS

# %% [markdown]
# Similarly, we can look at examples of mentions that have been marked by our curators as **software**:

# %%
software_raw.sample(10)[['pmid', 'text', 'software']]
# Out:
#                 pmid  \
# 6447805   25054223.0
# 8734334   28321207.0
# 5327125   22530047.0
# 1530508   24559402.0
# 128627    21754056.0
# 12779804  33761993.0
# 11536578  29367613.0
# 11465334  28860520.0
# 14745678  29382111.0
# 8523333   23630489.0
#
#                                                                                                                                                                                                                                                                                                                                                                                               text  \
# 6447805                                                                                                                                                                                                                                       Profiles were analyzed with the online analysis tools DAVID and STRING to identify enrichment for specific pathways and protein-protein interactions
# 8734334                                                                                                                                                                                                                                                                       ResFinder is also not capable of detecting point mutations in genes such as gyrA that lead to a resistance phenotype
# 5327125                                                                                                                                                                      All of these proteins were analyzed with Ingenuity Pathway Analysis (IPA) software to disclose connections between these proteins, and thus define pathways that could be involved in the molecular mechanisms of MS.
# 1530508                                                                                                                                                                                                                                                     Upper part of the plot shows the read coverage, middle part the reads and lower part the transcripts defined by Cufflinks as blue bars
# 128627    Data collection: CrystalClear (Rigaku, 2009 ▶); cell refinement: CrystalClear; data reduction: CrystalClear; program(s) used to solve structure: SHELXS97 (Sheldrick, 2008 ▶); program(s) used to refine structure: SHELXL97 (Sheldrick, 2008 ▶); molecular graphics: SHELXTL (Sheldrick, 2008 ▶); software used to prepare material for publication: CrystalStructure (Rigaku, 2009 ▶).
# 12779804                                                                                                                                                                                                                                                                                                                         Band intensity was quantified using the ImageJ software (1.44 P).
# 11536578                                                                                                                                                                                         Intron-spanning primers for Cdc42 (Genbank accession number: U37720.1) and GAPDH (GU214026.1) were designed using Primer3 and synthesized by Integrated DNA Technologies (Skokie, IL) as follows:
# 11465334                                                                                                                                                                                                                 Using the function “bioenv” in the vegan package in R, TN was found to be the most correlated factor among all the soil chemical properties (SCPs) and their combinations
# 14745678                                                                                                                                                                                                        All statistical analyses were performed using SPSS 13.0 statistical software (SPSS Inc., Chicago, IL, USA), and p values less than 0.05 were considered statistically significant.
# 8523333                                                                                                                                                                       Ocular artifact rejection was carried out using the Neuroscan Edit transform (derived from Semlitsch et al., 1986) followed by a second, automatic artifact rejection sweep, with exclusion parameters set at ±75 mV
#
#                                   software
# 6447805                              DAVID
# 8734334                          ResFinder
# 5327125   Ingenuity Pathway Analysis (IPA)
# 1530508                          Cufflinks
# 128627                        CrystalClear
# 12779804                            ImageJ
# 11536578                           Primer3
# 11465334                                 R
# 14745678                              SPSS
# 8523333                          Neuroscan

# %% [markdown]
# Same for **unclear**:

# %%
unclear_raw.sample(10)[['pmid', 'text', 'software']]
# Out:
#                 pmid  \
# 10508661  23497556.0
# 3616993   31367295.0
# 8996379   29456487.0
# 10273477  33676583.0
# 2507809   22734688.0
# 8850621   33154741.0
# 10088141  33301553.0
# 7847277   23482063.0
# 7763542   31346416.0
# 3690776   32781747.0
#
#                                                                                                                                                                                                                                                                                                                               text  \
# 10508661                                                                                                                                                                                              We used SHARE in our early experiments on HAI-related semantic querying for Clinical Intelligence purposes, reported in [19]
# 3616993                                                                                                                                                                                                                                                Statistical analysis was performed using SAS software and GraphPad Prism 5.
# 8996379                                                  In particular, for the finest mesh resolution of 1 mm sources with a distance of 1.59 mm from the brain-CSF surface, DG-FEM yielded mean topographical errors (relative difference measure, RDM%) of 1.5% and mean magnitude errors (MAG%) of 0.1% for the magnetic field
# 10273477                                                                                                                                                    Conclusion Urologists and staff affiliated with MUSIC implementation sites indicated that P3P focuses the treatment discussion on items that are important to patients
# 2507809                                                                                                                                                            This work suggests that, at least when applied in combination with other modeling methods, MSA can extract meaningful information from wild-type-only data sets
# 8850621                                                                                                                                                                                                                                  HERFD-XANES data treatment was performed using ATHENA software (Ravel and Newville, 2005)
# 10088141                                                                                                                                                                                   For additional comparison, we applied VISION and PAGODA to the interferon stimulation and blood development datasets (Supplementary Fig
# 7847277                                                                                                                                                                                           All analyses were conducted using SAS software (version 9.2) and R 2.12.1 (R Project for Statistical Computing, Vienna, Austria)
# 7763542   Estimates of genetic diversity, including average number of alleles per locus (A), observed and expected heterozygosity (H o and H e respectively), and the inbreeding coefficient (f), were calculated with GDA 1.1 (Lewis & Zaykin, 2001), while allelic richness (A r) was calculated with FSTAT 2.9.3 (Goudet, 1995)
# 3690776                                                                                                                                                                                   We used an analysis of cell viability, flow cytometry, the IncuCyte live-cell analysis system, and Western blotting to study its effects
#
#           software
# 10508661     SHARE
# 3616993        SAS
# 8996379        FEM
# 10273477     MUSIC
# 2507809        MSA
# 8850621     ATHENA
# 10088141    VISION
# 7847277        SAS
# 7763542        GDA
# 3690776   IncuCyte

# %% [markdown]
# Note that for mentions that are marked as **unclear**, we don't recommend excluding them from analyses. They should rather be interpreted as *it cannot be assumed that this plain-text software mention will always be a true software mention when appearing in text*. The curators have only been provided with 5 sentences per software mention, and they did not curate each individual sentence in which a mention appears. The evaluations are based solely on those 5 sentences. We offer a more in-depth discussion about this in our [preprint](https://arxiv.org/abs/2209.00693) and [curation documents](link)

# %% [markdown]
# This means that if we wanted to clean our dataset, we should only exclude the mentions markes as **not_software**:

# %%
raw_df_clean = raw_df[raw_df['curation_label'] != 'not_software']

# %% [markdown]
# Looking at the top mentions again:

# %%
raw_df_clean_aggregated = raw_df_clean.groupby('software').nunique().sort_values(by = 'pmid', ascending = False)
raw_df_clean_aggregated[:30]
# Out:
#                  license  location   pmcid    pmid     doi  pubdate  source  \
# software
# SPSS                   1    286647  286647  285279  279566       22   31053
# R                      1    192460  192460  191817  191636       21  101864
# GraphPad Prism         1    119661  119661  119357  118576       19   27484
# ImageJ                 1     94715   94715   94428   93950       19   76479
# Excel                  1     80247   80247   79826   79447       24   33460
# GraphPad               1     75614   75614   75438   74900       19   14637
# SAS                    1     75133   75133   74919   74596       23   15059
# BLAST                  1     54981   54981   54870   54660       24   54508
# Stata                  1     46462   46462   46279   46175       20    7807
# MATLAB                 1     46532   46532   46265   46417       21   39037
# SPSS Statistics        1     38049   38049   37875   37858       14    5225
# STATA                  1     34310   34310   34149   34037       19    5365
# Prism                  1     32221   32221   32155   31936       20    9567
# Matlab                 1     31191   31191   30967   31091       20   24623
# Image J                1     30905   30905   30835   30465       19   22244
# FlowJo                 1     29058   29058   29008   28726       18   16923
# MEGA                   1     24099   24099   24059   23997       19   15776
# SHELXL97               1     19266   19266   19265   19266       15     105
# Cytoscape              1     18147   18147   18072   18020       18   19499
# SHELXS97               1     17501   17501   17499   17500       15      72
# Ensembl                1     16951   16951   16915   16835       19   18842
# Adobe Photoshop        1     14393   14393   14370   14216       21    8913
# ClustalW               1     14248   14248   14231   14159       18   10506
# Python                 1     14108   14107   14001   14095       18   11032
# PACE                   1     13781   13781   13760   13778       16     110
# Statistica             1     13287   13287   13227   13192       18    3054
# DAVID                  1     13157   13157   13118   12997       19   13711
# SAINT                  1     12927   12927   12924   12927       16     416
# SHELXTL                1     11552   11552   11550   11552       17     260
# MAFFT                  1     11498   11498   11476   11486       18    7981
#
#                  number    text  version  ID  curation_label
# software
# SPSS                691  291953      836   1               1
# R                   662  299463     1042   1               1
# GraphPad Prism      295  129161      409   1               1
# ImageJ              349  159854      753   1               1
# Excel               444   96334      299   1               1
# GraphPad            240   76420      134   1               1
# SAS                 318   88060      292   1               1
# BLAST               287  100939      122   1               1
# Stata               355   52525      383   1               1
# MATLAB              375   77802      595   1               1
# SPSS Statistics     195   36057      208   1               1
# STATA               287   37892      301   1               1
# Prism               231   35683      272   1               1
# Matlab              326   48311      464   1               1
# Image J             195   43781      337   1               1
# FlowJo              209   33137      260   1               1
# MEGA                183   35867      335   1               1
# SHELXL97             54    7164        0   1               1
# Cytoscape           225   39448      198   1               1
# SHELXS97             46    6009        0   1               1
# Ensembl             239   37432      156   1               1
# Adobe Photoshop     187   16016      288   1               1
# ClustalW            182   19473       48   1               1
# Python              312   19917      194   1               1
# PACE                705     362        1   1               1
# Statistica          152   13543      155   1               1
# DAVID               218   28453       42   1               1
# SAINT                91    4077        3   1               1
# SHELXTL              66    3398        4   1               1
# MAFFT               185   16177      157   1               1

# %% [markdown]
# <a id='dataset_interaction_disambiguated_freq_samples'></a>
# Now, by looking at the most frequent mentions on the dataset above, we can make another observation. There seem to be plain-text software mentions that point to the same software. For Instance:
# - **SPSS** and **SPSS Statistics** are the same software **SPSS**,
# - **GraphPad Prism**, **GraphPad** and **Prism** are likely pointing to the same software **GraphPad Prism**
# - **MATLAB** and **Matlab**
# - **ImageJ** and **Image J**
#
# If we want to gauge the full impact of a piece of software, we should aggregate the impact of all of its string variations. This is the issue we address in the section below.

# %% [markdown]
# <a id='dataset_interaction_disambiguated'></a>
# ### disambiguated files
#
# Through disambiguation, the goal is to cluster together plain-text software mentions that point to the same software entity. In this section, we go over a [short description of the motivation](#dataset_interaction_disambiguated_motivation'), as well as some examples of engaging with the disambiguated dataset. More in-depth details about the disambiguation algorithm, which is based on string similarity algorithms and [DBSCAN](#references_dbscan), can be found in our preprint, as well as under our Github repository page.
#
#
# The **disambiguated** files contain plain-text mentions, as extracted by the NER model, mapped to software entities, as determined by our disambiguation algorithm. There is only one file to interact with:
# - comm_disambiguated.tsv.gz
#
# The file is quite large and stored as GZIP archive. Similarly to the [**raw** datasets](#dataset_interaction_raw), if you are using pandas, we recommend opening using the following. We also offer an example of reading only the first 1000000 rows. For querying the entire dataset, please remove this constraint and run:

# %%
disambiguated_df = pd.read_csv(ROOT_DATA_DIR + 'disambiguated/comm_disambiguated.tsv.gz', sep = '\\t', engine = 'python', compression = 'gzip')

# %%
# disambiguated_df = pd.read_csv(ROOT_DATA_DIR + 'disambiguated/comm_disambiguated.tsv.gz', sep = '\\t', engine = 'python', compression = 'gzip')

# %% [markdown]
# Note that due to its size, reading the entire file will take quite a long time to open (~20 min)

# %% [markdown]
# Let's start by looking at a few samples:

# %%
pd.set_option('max_colwidth', 50)
disambiguated_df.sample(3)
# Out:
#         license                              location    pmcid        pmid  \
# 1340683    comm    comm/BMC_Evol_Biol/PMC3560262.nxml  3560262  23186303.0
# 2544450    comm              comm/BMJ/PMC6371944.nxml  6371944  30755451.0
# 9283459    comm  comm/Front_Plant_Sci/PMC5562724.nxml  5562724  28861102.0
#
#                               doi  pubdate  \
# 1340683  10.1186/1471-2148-12-228     2012
# 2544450          10.1136/bmj.l236     2019
# 9283459   10.3389/fpls.2017.01422     2017
#
#                                                     source  number  \
# 1340683        Complex patterns of component re-assortment      69
# 2544450                                        paper_title       0
# 9283459  Transcript Assembly, Sequence Alignment and Qu...       5
#
#                                                       text   software version  \
# 1340683  Importantly, our second BEAST-based approach p...      BEAST     NaN
# 2544450  Effectiveness and safety of electronically del...     REDUCE     NaN
# 9283459  To obtain expression profiles and predict gene...  Cufflinks     NaN
#
#              ID curation_label mapped_to_software
# 1340683   SM681       software              BEAST
# 2544450  SM9911        unclear             REDUCE
# 9283459   SM624       software          Cufflinks

# %% [markdown]
# We can look at the fields we have available

# %%
disambiguated_df.columns
# Out:
# Index(['license', 'location', 'pmcid', 'pmid', 'doi', 'pubdate', 'source',
#        'number', 'text', 'software', 'version', 'ID', 'curation_label',
#        'mapped_to_software'],
#       dtype='object')

# %% [markdown]
# The fields in this dataset are largely the same as the ones in the **raw** dataset. As a reminder:
# - **software** : the software mention extracted by the NER algorithm from **text**
# - **version** : software version as extracted by the NER algorithm (note that not all mentions will have this)
# - **text** : text that **software** is being extracted from
# - **curation_label** : label assigned to software mention by our curators
#
# These are all fields we've seen before in the **raw** dataset. However, now we get an extra field:
#
# - **mapped_to_software** : software entity (or cluster) the **software** mention is predicted to be part of; this is the result of disambiguation
#
# As a reminder, for a full definition of all of the fields, please take a look at the [Dataset_README.md](link) file in our [Github repo](https://github.com/chanzuckerberg/software-mentions).
#
# Now let's get started exploring the disambiguated dataset!

# %% [markdown]
# For mentions we were not able to disambiguate, we set the **mapped_to_software** field to the value of the **software** mention itself.

# %%
def populate_map_to_software(x):
    if x['mapped_to_software'] == 'not_disambiguated':
        return x['software']
    return x['mapped_to_software']

# %%
disambiguated_df['mapped_to_software'] = disambiguated_df.apply(populate_map_to_software, axis = 1)

# %% [markdown]
# <a id='dataset_interaction_disambiguated_motivation'></a>
# #### 1. Why do we need disambiguation?
#
# First, let's understand more why we would want to disambiguate the software mentions.
# [In the previous section](#dataset_interaction_disambiguated_freq_samples), we already started to see that the same software can be extracted by the NER model from a paper under different string variations. Let's look at a few more examples, to drive the point home.

# %% [markdown]
# <a id='dataset_interaction_disambiguated_motivation_scipy'></a>
# ##### SciPy
# We have already looked at **SciPy** in the previous section. But *'SciPy'* is not the only string variation authors can mention the software **SciPy** in their papers, or in which the NER model might extract a string that points to the **SciPy** software entry. Some possible variations that the NER model could extract are: `['scipy', 'Scipy', 'SciPy', 'SCIPY']`. Let's see  how these can appear in the dataset. <br>
# Note that for simplification, we're only outputting the **pmid**, **text** and **software**.

# %%
relevant_fields = ['pmid', 'text', 'software']
num_samples = 5
raw_df[raw_df['software'] == 'scipy'][relevant_fields][:num_samples]
# Out:
#              pmid                                               text software
# 8488   33556239.0  The 83.4% confidence interval for the mean was...    scipy
# 9849   33449631.0  Wavelength was computed using scipy FFT and pe...    scipy
# 9853   33449631.0  Signal analysis (FFT) and visualization were c...    scipy
# 9857   33449631.0  Wavelength was computed using scipy FFT and pe...    scipy
# 19111  34542700.0  Parameter optimisation was performed with the ...    scipy

# %%
raw_df[raw_df['software'] == 'Scipy'][relevant_fields][:num_samples]
# Out:
#               pmid                                               text software
# 29105   32356790.0  Initially we use the widely applied damped lea...    Scipy
# 274113  33042750.0  Statistical analyses were performed using Pyth...    Scipy
# 278446  28261545.0  The core components of the Nanosurveyor stream...    Scipy
# 459150  31739644.0  The NumPy numerical software library [74] was ...    Scipy
# 459152  31739644.0  Matplotlib [76] package was used to obtain the...    Scipy

# %%
raw_df[raw_df['software'] == 'SciPy'][relevant_fields][:num_samples]
# Out:
#              pmid                                               text software
# 8827   34156229.0  The system of differential equations describin...    SciPy
# 9462   34308060.0  As one drainage curve was obtained by averagin...    SciPy
# 29275  27126118.0  The length and direction of the ellipse axes a...    SciPy
# 29375  31692460.0  The pairing of acentric anomalous reflections ...    SciPy
# 29390  31692460.0  The paired intensities were also the basis of ...    SciPy

# %%
raw_df[raw_df['software'] == 'SCIPY'][relevant_fields][:num_samples]
# Out:
#                pmid                                               text  \
# 908446   26051821.0  The library relies on some standard Python lib...
# 908455   26051821.0  Also, statistical routines provided by SCIPY a...
# 2883581  32182929.0  Moreover, we compute pressure gradients along ...
# 3370011  30213144.0  The programme script for data conditioning was...
# 3544433  31835464.0  Statistical analysis has been performed in QII...
#
#         software
# 908446     SCIPY
# 908455     SCIPY
# 2883581    SCIPY
# 3370011    SCIPY
# 3544433    SCIPY

# %% [markdown]
# Let's look at a few more examples! Note that in each case, we are only showcasing a **few** string variations as an example. However, software entities can have hundreds of string variations, as extracted by the NER model. For more examples of this and a discussion, please visit our preprint.

# %% [markdown]
# <a id='dataset_interaction_disambiguated_motivation_BLAST'></a>
# ##### BLAST
# Some example of string variations can be: `['BLAST', '(BLAST)', 'BLAST Whole Genome', 'BLAST) search']`

# %%
raw_df[raw_df['software'] == 'BLAST'][relevant_fields][:num_samples]
# Out:
#             pmid                                               text software
# 1388  28324466.0  Comparative analysis was performed through BLA...    BLAST
# 1389  28324466.0  When non-homologous 406 sequences were aligned...    BLAST
# 1394  28324466.0            Complete BLAST alignments were two-way.    BLAST
# 1398  28324466.0  KAAS provides functional annotation of genes b...    BLAST
# 1401  28324450.0  The sequence data was checked by BLAST analysi...    BLAST

# %%
raw_df[raw_df['software'] == '(BLAST)'][relevant_fields][:num_samples]
# Out:
#                pmid                                               text  \
# 2250317  31455245.0  The phylogenetic analysis was performed with t...
# 2531584  24074037.0  Basic local alignment search tool (BLAST) anal...
# 7856314  34154664.0  For all datasets, taxonomic identification was...
# 8672076  26483785.0  Peptide prediction was performed by the IMG/M-...
# 9729246  33238553.0  We analyzed HSP protein sequences using Protei...
#
#         software
# 2250317  (BLAST)
# 2531584  (BLAST)
# 7856314  (BLAST)
# 8672076  (BLAST)
# 9729246  (BLAST)

# %%
raw_df[raw_df['software'] == 'BLAST Whole Genome'][relevant_fields][:num_samples]
# Out:
#                pmid                                               text  \
# 1599222  26444974.0  Through this tool, users can perform nucleotid...
# 7533548  27616775.0  Using the BLAST tools, users can perform nucle...
#
#                    software
# 1599222  BLAST Whole Genome
# 7533548  BLAST Whole Genome

# %%
raw_df[raw_df['software'] == 'BLAST) search'][relevant_fields][:num_samples]
# Out:
#                pmid                                               text  \
# 9688334  29495353.0  Through a conserved domain basic local alignme...
#
#               software
# 9688334  BLAST) search

# %% [markdown]
# <a id='dataset_interaction_disambiguated_motivation_sklearn'></a>
# ##### scikit-learn
#
# Example string variations:
# `['scikit-learn', 'scikit-learn python package', 'scikit-learn python library', 'scikit-learn python', 'scikit-learn library for Python', 'scikit-learn Python package2223']`

# %%
raw_df[raw_df['software'] == 'scikit-learn'][relevant_fields][:num_samples]
# Out:
#              pmid                                               text  \
# 8485   33556239.0  Local cluster density analysis was performed b...
# 8487   33556239.0  Nearest neighbor analysis was performed as a k...
# 18919  27699703.0  The software scikit-learn 0.17 (http://scikit-...
# 36782  25945580.0  We then used scikit-learn v.0.13.1 (Pedregosa ...
# 41236  25760616.0  The SVM classifier was implemented with the us...
#
#            software
# 8485   scikit-learn
# 8487   scikit-learn
# 18919  scikit-learn
# 36782  scikit-learn
# 41236  scikit-learn

# %%
raw_df[raw_df['software'] == 'scikit-learn python package'][relevant_fields][:num_samples]
# Out:
#                pmid                                               text  \
# 4483062  32932717.0  A partition of plant species was performed usi...
# 4641169  31658251.0  We then use the average precision score of the...
# 5211977  30444868.0  Computations were performed using the LassoLar...
# 8704869  33324368.0  Patterns of variance were investigated using p...
#
#                             software
# 4483062  scikit-learn python package
# 4641169  scikit-learn python package
# 5211977  scikit-learn python package
# 8704869  scikit-learn python package

# %%
raw_df[raw_df['software'] == 'scikit-learn python library'][relevant_fields][:num_samples]
# Out:
#                 pmid                                               text  \
# 10625992  26855674.0  Classifiers chain and binary relevance models ...
# 14178053  34203866.0  For all classification algorithms we used the ...
# 14229776  33211021.0  To address this question, we trained naïve Bay...
#
#                              software
# 10625992  scikit-learn python library
# 14178053  scikit-learn python library
# 14229776  scikit-learn python library

# %%
raw_df[raw_df['software'] == 'scikit-learn python'][relevant_fields][:num_samples]
# Out:
#                 pmid                                               text  \
# 4018106   34250262.0  The dataset was divided in 4 clusters using th...
# 5281565   31644551.0  First, the patients were divided into two clus...
# 8327865   32063839.0  This data reduction step used the default recu...
# 9717103   32244427.0  PCA+kmeans: Here PCA and kmeans functions from...
# 10651581  34372940.0  Cross-validation studies were carried out usin...
#
#                      software
# 4018106   scikit-learn python
# 5281565   scikit-learn python
# 8327865   scikit-learn python
# 9717103   scikit-learn python
# 10651581  scikit-learn python

# %%
raw_df[raw_df['software'] == 'scikit-learn library for Python'][relevant_fields][:num_samples]
# Out:
#                pmid                                               text  \
# 2087705  31195972.0  LASSO regressions of the three SCFAs and lacta...
#
#                                 software
# 2087705  scikit-learn library for Python

# %%
raw_df[raw_df['software'] == 'scikit-learn Python package2223'][relevant_fields][:num_samples]
# Out:
#                 pmid                                               text  \
# 11255682  27113018.0  In this study, we use the gaussian_process mod...
#
#                                  software
# 11255682  scikit-learn Python package2223

# %% [markdown]
# <a id='dataset_interaction_disambiguated_motivation_ImageJ'></a>
# ##### ImageJ
#
# Example string variations:
# `['ImageJ', 'Image J']`

# %%
raw_df[raw_df['software'] == 'ImageJ'][relevant_fields][:num_samples]
# Out:
#             pmid                                               text software
# 105   33134427.0  The obtained images were processed by ImageJ (...   ImageJ
# 728   30725341.0  The ImageJ software platform (National Institu...   ImageJ
# 740   31696334.0  All the measurements were performed using Aviz...   ImageJ
# 1213  30923948.0  Once the photograph was imported into an image...   ImageJ
# 1224  30923948.0  Once the photograph was imported into an image...   ImageJ

# %%
raw_df[raw_df['software'] == 'Image J'][relevant_fields][:num_samples]
# Out:
#             pmid                                               text software
# 1214  30923948.0  a Digital photograph exported from Image J wit...  Image J
# 1222  30923948.0  The photographs were imported into Image J dig...  Image J
# 1226  30923948.0  Digital photographs with embedded measurements...  Image J
# 1229  30923948.0  a Digital photograph exported from Image J wit...  Image J
# 1333  30715677.0  Microneedle physical dimensions (height, width...  Image J

# %% [markdown]
# <a id='dataset_interaction_disambiguated_motivation_MATLAB'></a>
# #### MATLAB
# Example string variations:
# `['MaTLab', 'MatLAB', 'MatLab', 'Matlab', 'MATLAB, Statistics and Machine Learning Toolbox', 'mAtLab)', 'Matlab)']`

# %%
raw_df[raw_df['software'] == 'MaTLab'][relevant_fields][:num_samples]
# Out:
#                 pmid                                               text  \
# 3091108   29623956.0            The coding was done using MaTLab 2016b.
# 13246865  18387189.0  The model was realized with a combination of M...
# 13246867  18387189.0  The MaTLab program calculates the plume from a...
#
#          software
# 3091108    MaTLab
# 13246865   MaTLab
# 13246867   MaTLab

# %%
raw_df[raw_df['software'] == 'MatLAB'][relevant_fields][:num_samples]
# Out:
#                pmid                                               text  \
# 245819   20809745.0  Custom-written software in MatLAB (version 7.0...
# 274930   30937256.0  Videos were taken using Zeiss Axiocam ERc 5s (...
# 313798   32589613.0  Data were statistically analyzed using MatLAB ...
# 646735   19828075.0  A last set of implemented queries allows the P...
# 2592774  26425412.0  We provide a sample MatLAB code (Supporting In...
#
#         software
# 245819    MatLAB
# 274930    MatLAB
# 313798    MatLAB
# 646735    MatLAB
# 2592774   MatLAB

# %%
raw_df[raw_df['software'] == 'MaTLab'][relevant_fields][:num_samples]
# Out:
#                 pmid                                               text  \
# 3091108   29623956.0            The coding was done using MaTLab 2016b.
# 13246865  18387189.0  The model was realized with a combination of M...
# 13246867  18387189.0  The MaTLab program calculates the plume from a...
#
#          software
# 3091108    MaTLab
# 13246865   MaTLab
# 13246867   MaTLab

# %%
raw_df[raw_df['software'] == 'MatLab'][relevant_fields][:num_samples]
# Out:
#             pmid                                               text software
# 1335  30715677.0  In order to investigate the influence of alias...   MatLab
# 1336  30715677.0  When any portion of the desired microneedle ar...   MatLab
# 1337  30715677.0  The MatLab code was used to produce image slic...   MatLab
# 1338  30715677.0  In order to alter the aspect ratio and spacing...   MatLab
# 1339  30715677.0  To vary spacing, slices of microneedles measur...   MatLab

# %%
raw_df[raw_df['software'] == 'Matlab'][relevant_fields][:num_samples]
# Out:
#            pmid                                               text software
# 268  33507428.0  All parameters in each specimen were measured ...   Matlab
# 406  33141272.0  Statistical analyses were performed in Matlab ...   Matlab
# 411  33141272.0  A Students t-test was performed to determine i...   Matlab
# 495  33914200.0  The Strain-stress curves in the elastic region...   Matlab
# 501  33914200.0  The comparison of the strain-stress curves was...   Matlab

# %% [markdown]
# <a id='dataset_interaction_disambiguated_dataset_query'></a>
# #### Query the dataset for a particular software, including all string variations
#
# Great! So now that we saw the benefit of disambiguating the software terms, let's see how we can query our disambiguated dataset and interact with it. Let's start by going back to searching for the **scipy** entry. <BR>

# %%
software = 'scipy'
disambiguated_df[disambiguated_df['software'] == software].head(3)
# Out:
#      license                             location    pmcid        pmid  \
# 8488    comm        comm/ACS_Nano/PMC7905882.nxml  7905882  33556239.0
# 9849    comm  comm/ACS_Synth_Biol/PMC8486170.nxml  8486170  33449631.0
# 9853    comm  comm/ACS_Synth_Biol/PMC8486170.nxml  8486170  33449631.0
#
#                             doi  pubdate               source  number  \
# 8488    10.1021/acsnano.0c10632     2021     Cluster Analysis      40
# 9849  10.1021/acssynbio.0c00318     2021          fig_caption       5
# 9853  10.1021/acssynbio.0c00318     2021  Computational Model      12
#
#                                                    text software version  \
# 8488  The 83.4% confidence interval for the mean was...    scipy     NaN
# 9849  Wavelength was computed using scipy FFT and pe...    scipy     NaN
# 9853  Signal analysis (FFT) and visualization were c...    scipy     NaN
#
#           ID curation_label mapped_to_software
# 8488  SM3076       software              SciPy
# 9849  SM3076       software              SciPy
# 9853  SM3076       software              SciPy

# %% [markdown]
# We see that the **mapped_to_software** field for the entries in which **software** is **scipy** is **SciPy**, which means that the plain-text software mention **scipy** got mapped to the **SciPy** software entity through disambiguation. We can also obtain this by:

# %%
mapped_to = disambiguated_df[disambiguated_df['software'] == software]['mapped_to_software'].values[0]
print('The', software, 'mention got mapped to the', mapped_to, 'software entity')
# Out:
# The scipy mention got mapped to the SciPy software entity

# %%
mapped_to
# Out:
# 'SciPy'

# %% [markdown]
# Now, let's look at all the other entries that got mapped to the same entry:

# %%
mapped_to_df = disambiguated_df[disambiguated_df['mapped_to_software'] == mapped_to]

# %% [markdown]
# Now we can retrieve all of the string variations that map to the same entry:

# %%
string_variations = mapped_to_df['software'].unique()
print('Here are other potential string variations for', software, 'as given by the disambiguation algorithm')
print(string_variations)
# Out:
# Here are other potential string variations for scipy as given by the disambiguation algorithm
# ['scipy' 'SciPy' 'Scipy' 'SciPy Python package' 'Python-SciPy'
#  'SciPy Python library' 'python-scipy' 'scipy Python'
#  'Scipy Python package' 'Scipy1' 'Python scipy' 'Python Scipy package'
#  'Python SciPy' 'scipy python library' 'SciPy python package'
#  'Scipy Python library' 'Python-Scipy' 'SciPy3' 'scipy Python package'
#  'SciPY' 'scipy python package' 'scipy29' 'Scipy python library'
#  'Python Scipy' 'Python SciPy package' 'Python SciPy library'
#  'Python scipy package' 'SciPy Python packages' 'Python scipy library'
#  'python scipy package' 'Scipy Python Library' 'python scipy'
#  'Python Scipy library' 'Scipy Python' 'sciPy' 'SciPy80'
#  'Scientific Tools for Python' 'SciPy7' 'SciPy, Python library'
#  'scipy python' 'scipy Python library' 'Scipy python' 'scipy®' 'scipy16'
#  'SCIPy' 'SciPy30' 'SciPy62' 'SciPy42' 'SciPy52' 'SciPy79'
#  'SciPy Python Library' 'scipy)' 'Python/Scipy' 'SciPy)'
#  'Python package scipy' 'SciPy +']

# %% [markdown]
# <a id='dataset_interaction_disambiguated_examples'></a>
# #### Examples of disambiguated software terms
#
# Now let's look at a few more examples! For the software mentions below, we will retrieve the software entity they get mapped to, and what other string variations they can appear under

# %%
software_mentions = ['BLAST', 'sklearn', 'SciPy', 'SPSS', 'ImageJ', 'limma', 'BERT', 'scikit-image', 
                    'GraphPad Prism']

for software in software_mentions:
    mapped_to = disambiguated_df[disambiguated_df['software'] == software]['mapped_to_software'].values[0]
    mapped_to_df = disambiguated_df[disambiguated_df['mapped_to_software'] == mapped_to]
    string_variations = mapped_to_df['software'].unique()
    print(software, 'got mapped to the', mapped_to, 'software entity')
    print('There are', len(string_variations), 'other potential string variations')
    print('Some of these are:')
    print('='*30)
    print(string_variations[:50]) #only printing 50 for visibility
# Out:
# BLAST got mapped to the BLAST software entity
# There are 309 other potential string variations
# Some of these are:
# ==============================
# ['BLAST' 'BLASTP' 'Blastp' 'blastp' 'blast' 'BlastP' 'BLAST search'
#  'BLAST®' 'BLASTp' 'BLASTs' 'BLAST+' 'Blast search' 'BLAST)'
#  'Basic Local Alignment Search Tool' 'BLAST-p' 'BLAST +' 'Blast' 'blastP'
#  'BLAST-P' 'Basic Local Alignment Search tool' 'blast search' 'blast+'
#  'BLAST-searches' 'BLAST-search' 'blast+ package' 'NCBI Blast'
#  'Basic local alignment search tool' 'Basic Local Alignment Search Tool74'
#  'Basic Local Alignment Search Tool)' 'BLAST10' 'BLAST14' 'BLAST37'
#  'Blast +' 'Blastp)' '(Basic Local Alignment Search Tool)' 'ncbi-blast'
#  'Basic Local Alignment Search Tool®' 'blastP)' 'NCBI-BLAST'
#  'blastp suite' 'BLAST.P' 'BLAST+ package' 'BLASTS' 'ncbi - blast +'
#  'BLASTP2' 'BLAST2' 'NCBI-BLAST+' 'BLAST package' 'BLAST2P' 'BLAST3']
# sklearn got mapped to the scikit-learn software entity
# There are 124 other potential string variations
# Some of these are:
# ==============================
# ['Scikit-Learn' 'scikit-learn Python' 'scikit-learn' 'Scikit learn'
#  'sklearn' 'scikit-learn Python library' 'Scikit-learn' 'Sklearn'
#  'Python scikit-learn' 'scikit learn' 'scikit‐learn' 'Scikit‐learn'
#  'Scikit-Learn Python' 'scikit-learn81' 'SciKit-Learn' 'sklearn Python'
#  'Python package scikit-learn' 'Scikit-learn Python library'
#  'Scikit Learn5' 'Scikit-learn Python package' 'Sci-Kit Learn'
#  'Python Scikit-learn' 'Scikit Learn' 'scikit-learn Python package'
#  'Python Scikit-learn library' 'Sci-kit Learn'
#  'Python scikit-learn package' 'sci-kit learn' 'Scikit Learn Python'
#  'SciKit Learn' 'scikit-learn2' 'Python scikit-learn library'
#  'Sci-kit learn' 'Scikit-learn Python' 'Python Sklearn library'
#  'Sklearn Python' 'Scikit-learn29' 'scikits-learn' 'Python Sklearn'
#  'sci-kit-learn' 'scikit_learn' 'SciKit-learn Python library' 'SkLearn'
#  'scikit -learn' 'Python Scikit-Learn' 'Python3 sklearn' 'SciKitLearn'
#  'scikitlearn' 'ScikitLearn' 'SciKit-learn']
# SciPy got mapped to the SciPy software entity
# There are 56 other potential string variations
# Some of these are:
# ==============================
# ['scipy' 'SciPy' 'Scipy' 'SciPy Python package' 'Python-SciPy'
#  'SciPy Python library' 'python-scipy' 'scipy Python'
#  'Scipy Python package' 'Scipy1' 'Python scipy' 'Python Scipy package'
#  'Python SciPy' 'scipy python library' 'SciPy python package'
#  'Scipy Python library' 'Python-Scipy' 'SciPy3' 'scipy Python package'
#  'SciPY' 'scipy python package' 'scipy29' 'Scipy python library'
#  'Python Scipy' 'Python SciPy package' 'Python SciPy library'
#  'Python scipy package' 'SciPy Python packages' 'Python scipy library'
#  'python scipy package' 'Scipy Python Library' 'python scipy'
#  'Python Scipy library' 'Scipy Python' 'sciPy' 'SciPy80'
#  'Scientific Tools for Python' 'SciPy7' 'SciPy, Python library'
#  'scipy python' 'scipy Python library' 'Scipy python' 'scipy®' 'scipy16'
#  'SCIPy' 'SciPy30' 'SciPy62' 'SciPy42' 'SciPy52' 'SciPy79']
# SPSS got mapped to the SPSS software entity
# There are 1361 other potential string variations
# Some of these are:
# ==============================
# ['SPSS' 'SPSS Statistics' 'SPSS18' 'SPSS statistics' 'SPSS22' 'SPSS)'
#  'Statistical Package for Social Sciences' 'SPSS©'
#  'Statistical Package for Social Sciences (SPSS'
#  'Statistical Package for Social Science (SPSS'
#  'Statistical package for Social Sciences (SPSS)'
#  'Statistical Package for Social Science'
#  'Statistical Package for the Social Sciences (SPSS'
#  'Statistical Package for the Social Sciences (SPSS)'
#  'Statistical Package for the Social Sciences (SPSS®'
#  'Statistical Package for Social Sciences (SPSS)' 'SPPS statistics'
#  'SPSS16' 'SPSS®' 'Statical package for social sciences (SPSS)'
#  'Statistical Package for the Social Sciences (IBM SPSS)'
#  'Statistics Package of Social Sciences (SPSS' 'SPSS-16'
#  'Statistical Package of Social Science (SPSS' 'SPSS© Statistics'
#  'Statistical Package for the Social Scientist (SPSS)'
#  'Statistical Package for the Social Scientist (SPSS'
#  'Statistical Package for Social Science (SPSS)' 'SPSS-18'
#  'Statistical Package for the Social Sciences'
#  'Statistical Package for the Social Sciences® (SPSS)' 'spss'
#  'Statistical Package for Social Science (IBM SPSS)'
#  'Statistical Package for Social Sciences software'
#  'Statistical Package for Social Sciences SPSS'
#  'Statistical Package for the Social Sciences (SPSS®)'
#  'Statistical Package for Social Scientist software (SPSS)'
#  'Statistical Package for Social Sciences (SPSSx'
#  'Statistical Package of Social Science (SPSS)'
#  'Statistical Package for Social Science program (SPSS'
#  'Statistical Package of social Sciences'
#  'Statistical Package for the Social Sciences software (SPSS' 'SPSS13'
#  'SPSS Statistic' 'Statistical Package for Social Sciences [(SPSS)'
#  'SPSS19' 'SPSS17' 'SPSS-15' 'SPSS15' 'SPSS® Statistics']
# ImageJ got mapped to the ImageJ software entity
# There are 178 other potential string variations
# Some of these are:
# ==============================
# ['ImageJ' 'Image J' 'image J' 'Image-J' 'Image J1' 'imageJ' 'image j'
#  'Imagej' 'ImageJ®' 'Image J®' 'IMAGE-J®' 'Image-J®' 'image-J' 'ImageJ64'
#  'IMAGE J' 'ImageJ2' 'imagej' 'Image j' 'IMAGEJ' 'ImageJ30' 'imagej2'
#  'ImageJ1' 'ImageJ28' 'Image J2' 'Image J©' 'Image/J®' 'image/J®'
#  'Image J64' 'image-j' 'IMAGE-J' 'ImageJ-1'
#  'ImageJ (Image Processing and Analysis in Java' 'Image-j' 'Image J)'
#  'IMAGE j/' 'IMageJ' 'imageJ1' 'imageJ2' 'imageJ4' 'ImageJ4' 'ImageJ26'
#  'ImageJ©' 'imageJ®' 'ImageJ6' 'Image -J' 'ImageJ®1'
#  'ImageJ, Image Processing and Analysis in Java'
#  'ImageJ (Image Processing and Analysis in Java)'
#  'ImageJ Image Processing and Analysis in Java' 'Image J5']
# limma got mapped to the limma software entity
# There are 226 other potential string variations
# Some of these are:
# ==============================
# ['limma' 'Limma' 'limma bioconductor package' 'R package limma' 'LIMMA'
#  'limma package' 'Bioconductor limma' 'limma R-package'
#  'limma R/Bioconductor' 'limma-package' 'R package Limma'
#  'limma R package' 'R package “limma' 'Bioconductor Limma package'
#  'R Package limma' 'LIMMA)' 'Limma R package'
#  'Biocon-ductor limma package' 'limma R Bioconductor'
#  'Linear Models for Microarray Data (LIMMA)' 'Limma package'
#  'R package “ limma' 'limma Bioconductor'
#  'LInear Models for Microarray data (LIMMA)'
#  'Linear Models for Microarray Data (limma) R'
#  'Bioconductor R package Limma' 'Bioconductor Limma' '(Limma)'
#  'Bioconductor package limma' 'R/Bioconductor limma package'
#  'Linear Models for Microarray Data (limma)'
#  'Bioconductor R package limma' 'Limma Bioconductor Package'
#  'R-package limma' 'R-package Limma' 'limma Bioconductor package'
#  'limma Bioconductor R package' 'R/Bioconductor package limma'
#  'Linear Models for Microarray Data ( limma )'
#  'BioConductor package limma' 'limma bioconductor R package'
#  'limma BioConductor' 'R-package “limma' '(LIMMA)'
#  'LIMMA package (Linear Models for Microarray Data'
#  'limma package (Linear Models for Microarray Data)'
#  'Bioconductor LIMMA package' 'Bioconductor LIMMA'
#  'Bioconductor/R package Limma' 'R Bioconductor package Limma']
# BERT got mapped to the BERT software entity
# There are 2 other potential string variations
# Some of these are:
# ==============================
# ['BERT' 'bert']
# scikit-image got mapped to the scikit-image software entity
# There are 23 other potential string variations
# Some of these are:
# ==============================
# ['scikit-image' 'scikit-image Python' 'Python scikit-image library'
#  'Python scikit-image' 'scikit-image Python library' 'scikit-image5'
#  'scikit image' 'sci-kit image' 'scikit image Python'
#  'Python Scikit-image' 'Python Scikit-image library' 'Scikit-image'
#  'scikit-images' 'Scikit-Image' 'Python scikit-image package'
#  'Scikit-image Python' 'scikit-image Python package'
#  'scikit image Python package' 'scikit- image'
#  'Scikit-Image Python package' 'SCIKIT-IMAGE'
#  'Python package scikit-image' 'Scikit-image Python library']
# GraphPad Prism got mapped to the GraphPad Prism software entity
# There are 470 other potential string variations
# Some of these are:
# ==============================
# ['GraphPad Prism' 'GraphPad' 'Graph Pad' 'Graphpad Prism' 'GraphPad prism'
#  'Graph pad Prism5' 'Graph pad prism' 'Graph Pad Prism' 'Graph-Pad Prism'
#  'GraphPad Prism®' 'GraphPad-Prism' 'GraphPad PRISM' 'GRAPHPAD PRISM'
#  'Graphpad prism' 'Graphpad' 'GraphPad Prism7' 'Graph pad'
#  'Graph Pad Prismv' 'GraphPad Prism5' 'GraphPadPrism®' 'GraphPadPrism'
#  'GraphPad Prism5®' 'graphPad Prism' 'Graphpad Prism7' 'GraphPad)'
#  'graphpad' 'GraphPad Prism4' 'GraphPad (Prism)' 'Graph Pad PRISM'
#  'Graph-Pad' 'Graph Pad Prism4' 'GraphPad Prism®7' 'GraphPad Prismv5'
#  'Graph Pad prism' 'graphpad Prism' 'Graph pad Prism' 'Graphpad Prism8'
#  'Graphpad Prism4' 'graphPad' 'Graph PadPrism' 'Graphpad Prism6'
#  'GraphPad®' 'GraphPad Prism6' 'Graphpad PRISM' 'graphpad prism'
#  'Graph-pad prism' 'Graphpad Prism®' 'GraphPad Prisma' 'Graph-Pad PRISM'
#  'GraphPad prism 5']

# %% [markdown]
# <a id='dataset_interaction_disambiguated_most_frequent_mentions'></a>
#
# #### Example: Retrieve the most frequent software mentions based on disambiguated dataset
#
# Now let's look at getting the most frequent terms in our dataset, bassed on the **mapped_to** field
# It is the same command as on the [**raw** dataset](#dataset_interaction_raw_most_frequent_mentions), except that now we change the **software** field for the **mapped_to_software** field. Now the counts should be aggregated over *all* the string variations, as outputted by the disambiguation algorithm.

# %%
disambiguated_df_aggregated = raw_df.groupby('software').nunique().sort_values(by = 'pmid', ascending = False)
disambiguated_df_aggregated[:20]
# Out:
#                  license  location   pmcid    pmid     doi  pubdate  source  \
# software
# SPSS                   1    286647  286647  285279  279566       22   31053
# R                      1    192460  192460  191817  191636       21  101864
# GraphPad Prism         1    119661  119661  119357  118576       19   27484
# ImageJ                 1     94715   94715   94428   93950       19   76479
# Excel                  1     80247   80247   79826   79447       24   33460
# GraphPad               1     75614   75614   75438   74900       19   14637
# SAS                    1     75133   75133   74919   74596       23   15059
# BLAST                  1     54981   54981   54870   54660       24   54508
# Stata                  1     46462   46462   46279   46175       20    7807
# MATLAB                 1     46532   46532   46265   46417       21   39037
# SPSS Statistics        1     38049   38049   37875   37858       14    5225
# STATA                  1     34310   34310   34149   34037       19    5365
# Prism                  1     32221   32221   32155   31936       20    9567
# Matlab                 1     31191   31191   30967   31091       20   24623
# Image J                1     30905   30905   30835   30465       19   22244
# FlowJo                 1     29058   29058   29008   28726       18   16923
# MEGA                   1     24099   24099   24059   23997       19   15776
# COVID                  1     20990   20990   20163   20912        2   12618
# SHELXL97               1     19266   19266   19265   19266       15     105
# Cytoscape              1     18147   18147   18072   18020       18   19499
#
#                  number    text  version  ID  curation_label
# software
# SPSS                691  291953      836   1               1
# R                   662  299463     1042   1               1
# GraphPad Prism      295  129161      409   1               1
# ImageJ              349  159854      753   1               1
# Excel               444   96334      299   1               1
# GraphPad            240   76420      134   1               1
# SAS                 318   88060      292   1               1
# BLAST               287  100939      122   1               1
# Stata               355   52525      383   1               1
# MATLAB              375   77802      595   1               1
# SPSS Statistics     195   36057      208   1               1
# STATA               287   37892      301   1               1
# Prism               231   35683      272   1               1
# Matlab              326   48311      464   1               1
# Image J             195   43781      337   1               1
# FlowJo              209   33137      260   1               1
# MEGA                183   35867      335   1               1
# COVID               497   49213        4   1               1
# SHELXL97             54    7164        0   1               1
# Cytoscape           225   39448      198   1               1

# %% [markdown]
# Let's remind ourselves the most frequent terms on the raw dataset:

# %%
raw_df_aggregated[:20]
# Out:
#            software  license  location   pmcid    pmid     doi  pubdate  \
# 0              SPSS        1    286647  286647  285279  279566       22
# 1                 R        1    192460  192460  191817  191636       21
# 2    GraphPad Prism        1    119661  119661  119357  118576       19
# 3            ImageJ        1     94715   94715   94428   93950       19
# 4             Excel        1     80247   80247   79826   79447       24
# 5          GraphPad        1     75614   75614   75438   74900       19
# 6               SAS        1     75133   75133   74919   74596       23
# 7             BLAST        1     54981   54981   54870   54660       24
# 8             Stata        1     46462   46462   46279   46175       20
# 9            MATLAB        1     46532   46532   46265   46417       21
# 10  SPSS Statistics        1     38049   38049   37875   37858       14
# 11            STATA        1     34310   34310   34149   34037       19
# 12            Prism        1     32221   32221   32155   31936       20
# 13           Matlab        1     31191   31191   30967   31091       20
# 14          Image J        1     30905   30905   30835   30465       19
# 15           FlowJo        1     29058   29058   29008   28726       18
# 16             MEGA        1     24099   24099   24059   23997       19
# 17            COVID        1     20990   20990   20163   20912        2
# 18         SHELXL97        1     19266   19266   19265   19266       15
# 19        Cytoscape        1     18147   18147   18072   18020       18
#
#     source  number    text  version  ID curation_label
# 0    31053     691  291953      836   1       software
# 1   101864     662  299463     1042   1       software
# 2    27484     295  129161      409   1       software
# 3    76479     349  159854      753   1       software
# 4    33460     444   96334      299   1       software
# 5    14637     240   76420      134   1       software
# 6    15059     318   88060      292   1        unclear
# 7    54508     287  100939      122   1       software
# 8     7807     355   52525      383   1       software
# 9    39037     375   77802      595   1       software
# 10    5225     195   36057      208   1       software
# 11    5365     287   37892      301   1       software
# 12    9567     231   35683      272   1       software
# 13   24623     326   48311      464   1       software
# 14   22244     195   43781      337   1       software
# 15   16923     209   33137      260   1       software
# 16   15776     183   35867      335   1       software
# 17   12618     497   49213        4   1   not_software
# 18     105      54    7164        0   1       software
# 19   19499     225   39448      198   1       software

# %% [markdown]
# Note that the counts on the **disambiguated** and the **raw** dataset splits are different. This is because now, we are aggregating over multiple string variations for each string.

# %% [markdown]
# <a id='dataset_interaction_linked'></a>
# ### linked files
#
# We queried a number of databases, searching for exact matches for plain text sofware mentions in the `comm` collection. The databases we queryied are:
# - [PyPI Index](https://pypi.org/simple/)
# - [Bioconductor Index](https://www.bioconductor.org/packages/release/bioc/)
# - [CRAN Index](https://cran.r-project.org/web/packages/available_packages_by_name.html)
# - [GitHub API](https://github.com)
# - [SciCrunch API](https://scicrunch.org/resources)
#
# We describe in detail the methodology we used to obtain the links in our preprint, as well as in our [Github Repository](https://github.com/chanzuckerberg/software-mentions/tree/main/software-mentions-linker-disambiguator)
#
# We compiled this information in the `metadata.tsv.gz` file, which is assumed to be under the `linked` directory, as described in the [Interacting with the dataset Section](#dataset_interaction)

# %% [markdown]
# The **linked** files contain metadata links, extracted through the linking algorithm. There is only one file to interact with:
# - metadata.tsv.gz
#
# The file is also stored as GZIP archive. Similarly to the [**raw** datasets](#dataset_interaction_raw), if you are using pandas, we recommend opening using the following:

# %%
linked_df = pd.read_csv(ROOT_DATA_DIR + 'linked/metadata.tsv.gz', sep = '\\t', engine = 'python', compression = 'gzip', error_bad_lines = False)
# Out:
# Skipping line 79480: Expected 16 fields in line 79480, saw 17. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.

# %% [markdown]
# Let's start by looking at a few samples:

# %%
linked_df.sample(3)
# Out:
#                     ID software_mention  mapped_to      source platform  \
# 111136        SM288033             IDDM       IDDM  Github API      NaN
# 153189        SM796465        log4cplus  log4cplus  Github API      NaN
# 29929   volume = {21},             None       None        None     None
#
#                                    package_url  \
# 111136          https://github.com/emigmo/IDDM
# 153189  https://github.com/log4cplus/log4cplus
# 29929                                     None
#
#                                               description homepage_url  \
# 111136                                                NaN          NaN
# 153189  log4cplus is a simple to use C++ logging API p...          NaN
# 29929                                                None         None
#
#        other_urls license                             github_repo  \
# 111136        NaN     NaN          https://github.com/emigmo/IDDM
# 153189        NaN     NaN  https://github.com/log4cplus/log4cplus
# 29929        None    None                                    None
#
#        github_repo_license exact_match  RRID reference scicrunch_synonyms
# 111136                 NaN        True  None      None               None
# 153189                 NaN        True  None      None               None
# 29929                 None        None  None      None               None

# %% [markdown]
# We can look at the fields we have available

# %%
linked_df.columns
# Out:
# Index(['ID', 'software_mention', 'mapped_to', 'source', 'platform',
#        'package_url', 'description', 'homepage_url', 'other_urls', 'license',
#        'github_repo', 'github_repo_license', 'exact_match', 'RRID',
#        'reference', 'scicrunch_synonyms'],
#       dtype='object')

# %% [markdown]
# We describe the fields in details on the Github repository, under [Linking Schema](https://github.com/chanzuckerberg/software-mentions/tree/main/software-mentions-linker-disambiguator#linking-schema)
#
# Now let's explore the information we have available!

# %% [markdown]
# <a id='dataset_interaction_linked'></a>
# #### Examples of linked software terms
#
# Let's start by querying a number of software mentions, to see what links we get. We can start with the previous set of software mentions we looked at: ***'BLAST', 'sklearn', 'SciPy', 'SPSS', 'ImageJ', 'limma', 'BERT', 'scikit-image', 'GraphPad Prism'***

# %% [markdown]
# ##### BLAST

# %%
linked_df[linked_df['software_mention'] == 'BLAST']
# Out:
#           ID software_mention                mapped_to         source  \
# 41167  SM501            BLAST  BLAST Similarity Search  SciCrunch API
#
#       platform                                        package_url  \
# 41167      NaN  https://scicrunch.org/browse/resources/SCR_008419
#
#                                              description  \
# 41167  The goals of this sequencing effort are to pro...
#
#                                             homepage_url other_urls license  \
# 41167  ['http://www.broad.mit.edu/cgi-bin/annotation/...         []     NaN
#
#       github_repo github_repo_license exact_match        RRID  \
# 41167      [None]                 NaN       False  SCR_008419
#
#                                                reference  \
# 41167  [nan, '(BLAST Similarity Search, RRID:SCR_0084...
#
#                          scicrunch_synonyms
# 41167  ['blast similarity search', 'blast']

# %% [markdown]
# ##### sklearn

# %%
linked_df[linked_df['software_mention'] == 'sklearn']
# Out:
#            ID software_mention mapped_to         source platform  \
# 8276   SM3414          sklearn   sklearn     Pypi Index     Pypi
# 41751  SM3414          sklearn   Sklearn  SciCrunch API      NaN
# 60459  SM3414          sklearn   sklearn     Github API      NaN
#
#                                              package_url  \
# 8276                    https://pypi.org/project/sklearn
# 41751  https://scicrunch.org/browse/resources/SCR_019053
# 60459              https://github.com/KeithGalli/sklearn
#
#                                              description  \
# 8276   A set of python modules for machine learning a...
# 41751  Software Python package part of nonnegative ma...
# 60459  Data & Code associated with my tutorial on the...
#
#                                             homepage_url  \
# 8276      ['https://pypi.python.org/pypi/scikit-learn/']
# 41751  ['https://scikit-learn.org/stable/modules/gene...
# 60459                                                NaN
#
#                                               other_urls license  \
# 8276                                                 NaN     NaN
# 41751  ['https://github.com/scikit-learn/scikit-learn...     NaN
# 60459                                                NaN     NaN
#
#                                              github_repo github_repo_license  \
# 8276                                              [None]                 NaN
# 41751  ['https://github.com/scikit-learn/scikit-learn,']                 NaN
# 60459              https://github.com/KeithGalli/sklearn                 NaN
#
#       exact_match        RRID                            reference  \
# 8276         True        None                                 None
# 41751       False  SCR_019053  [nan, '(Sklearn, RRID:SCR_019053)']
# 60459        True        None                                 None
#
#       scicrunch_synonyms
# 8276                None
# 41751        ['sklearn']
# 60459               None

# %% [markdown]
# ##### SciPy

# %%
linked_df[linked_df['software_mention'] == 'SciPy']
# Out:
#            ID software_mention mapped_to         source platform  \
# 41719  SM3207            SciPy     SciPy  SciCrunch API      NaN
#
#                                              package_url  \
# 41719  https://scicrunch.org/browse/resources/SCR_008058
#
#                                              description  \
# 41719  A Python-based environment of open-source soft...
#
#                     homepage_url other_urls license github_repo  \
# 41719  ['http://www.scipy.org/']         []     NaN      [None]
#
#       github_repo_license exact_match        RRID  \
# 41719                 NaN        True  SCR_008058
#
#                                reference  \
# 41719  [nan, '(SciPy, RRID:SCR_008058)']
#
#                              scicrunch_synonyms
# 41719  ['scientific tools for python', 'scipy']

# %% [markdown]
# ##### SPSS

# %%
linked_df[linked_df['software_mention'] == 'SPSS']
# Out:
#           ID software_mention mapped_to         source platform  \
# 41139  SM165             SPSS      SPSS  SciCrunch API      NaN
# 60116  SM165             SPSS      SPSS     Github API      NaN
#
#                                              package_url  \
# 41139  https://scicrunch.org/browse/resources/SCR_002865
# 60116                    https://github.com/laribio/SPSS
#
#                                              description  \
# 41139  Software package used for interactive, or batc...
# 60116                                      SPSS workshop
#
#                                             homepage_url  \
# 41139  ['http://www-01.ibm.com/software/uk/analytics/...
# 60116                                                NaN
#
#                                       other_urls license  \
# 41139  ['https://www.ibm.com/products/software']     NaN
# 60116                                        NaN     NaN
#
#                            github_repo github_repo_license exact_match  \
# 41139                           [None]                 NaN        True
# 60116  https://github.com/laribio/SPSS                 NaN        True
#
#              RRID                         reference         scicrunch_synonyms
# 41139  SCR_002865  [nan, '(SPSS, RRID:SCR_002865)']  ['spss software', 'spss']
# 60116        None                              None                       None

# %% [markdown]
# ##### ImageJ

# %%
linked_df[linked_df['software_mention'] == 'ImageJ']
# Out:
#          ID software_mention mapped_to         source platform  \
# 41105  SM25           ImageJ    ImageJ  SciCrunch API      NaN
#
#                                              package_url  \
# 41105  https://scicrunch.org/browse/resources/SCR_003070
#
#                                              description  \
# 41105  Open source Java based image processing softwa...
#
#                   homepage_url  \
# 41105  ['https://imagej.net/']
#
#                                               other_urls license github_repo  \
# 41105  ['http://www.nitrc.org/projects/incf_imagej,',...     NaN      [None]
#
#       github_repo_license exact_match        RRID  \
# 41105                 NaN        True  SCR_003070
#
#                                                reference  \
# 41105  ['http://www.ncbi.nlm.nih.gov/pubmed/29187165,...
#
#                                       scicrunch_synonyms
# 41105  ['image j', 'imagej - image processing and ana...

# %% [markdown]
# ##### limma

# %%
linked_df[linked_df['software_mention'] == 'limma']
# Out:
#            ID software_mention mapped_to              source      platform  \
# 10649  SM2939            limma     limma  Bioconductor Index  Bioconductor
# 41685  SM2939            limma     LIMMA       SciCrunch API           NaN
# 60319  SM2939            limma     limma          Github API           NaN
#
#                                              package_url  \
# 10649  https://www.bioconductor.org/packages/release/...
# 41685  https://scicrunch.org/browse/resources/SCR_010943
# 60319                    https://github.com/mjktfw/limma
#
#                                              description  \
# 10649                  Linear Models for Microarray Data
# 41685  Software package for the analysis of gene expr...
# 60319  This is a read-only mirror of the Bioconductor...
#
#                                homepage_url  \
# 10649   ['http://bioinf.wehi.edu.au/limma']
# 41685  ['http://bioinf.wehi.edu.au/limma/']
# 60319                                   NaN
#
#                                               other_urls    license  \
# 10649                                                NaN  GPL (>=2)
# 41685  ['https://omictools.com/limma-tool,', 'https:/...        NaN
# 60319                                                NaN        NaN
#
#                            github_repo github_repo_license exact_match  \
# 10649                              NaN                 NaN        True
# 41685                           [None]                 NaN       False
# 60319  https://github.com/mjktfw/limma                 NaN        True
#
#              RRID                                   reference  \
# 10649         NaN  https://doi.org/doi:10.18129/B9.bioc.limma
# 41685  SCR_010943           [nan, '(LIMMA, RRID:SCR_010943)']
# 60319        None                                        None
#
#                                       scicrunch_synonyms
# 10649                                               None
# 41685  ['limma: linear models for microarray data', '...
# 60319                                               None

# %% [markdown]
# ##### BERT

# %%
linked_df[linked_df['software_mention'] == 'BERT']
# Out:
#             ID software_mention mapped_to         source platform  \
# 43698  SM25010             BERT      BERT  SciCrunch API      NaN
#
#                                              package_url  \
# 43698  https://scicrunch.org/browse/resources/SCR_018008
#
#                                              description  \
# 43698  Technique for Natural Language Processing pre-...
#
#                                       homepage_url other_urls license  \
# 43698  ['https://github.com/google-research/bert']         []     NaN
#
#                                        github_repo github_repo_license  \
# 43698  ['https://github.com/google-research/bert']                 NaN
#
#       exact_match        RRID                         reference  \
# 43698        True  SCR_018008  [nan, '(BERT, RRID:SCR_018008)']
#
#       scicrunch_synonyms
# 43698           ['bert']

# %% [markdown]
# ##### scikit-image

# %%
linked_df[linked_df['software_mention'] == 'scikit-image']
# Out:
#            ID software_mention     mapped_to         source platform  \
# 7884   SM3074     scikit-image  scikit-image     Pypi Index     Pypi
# 41698  SM3074     scikit-image  scikit-image  SciCrunch API      NaN
# 60373  SM3074     scikit-image  scikit-image     Github API      NaN
#
#                                              package_url  \
# 7884               https://pypi.org/project/scikit-image
# 41698  https://scicrunch.org/browse/resources/SCR_021142
# 60373       https://github.com/scikit-image/scikit-image
#
#                                              description  \
# 7884                          Image processing in Python
# 41698  Open source software tool as collection of ima...
# 60373                         Image processing in Python
#
#                         homepage_url other_urls                      license  \
# 7884    ['https://scikit-image.org']        NaN  OSI Approved :: BSD License
# 41698  ['https://scikit-image.org/']         []                          NaN
# 60373                            NaN        NaN                          NaN
#
#                                             github_repo github_repo_license  \
# 7884   ['https://github.com/scikit-image/scikit-image']                 NaN
# 41698                                            [None]                 NaN
# 60373      https://github.com/scikit-image/scikit-image                 NaN
#
#       exact_match        RRID  \
# 7884         True        None
# 41698        True  SCR_021142
# 60373        True        None
#
#                                                reference scicrunch_synonyms
# 7884                                                None               None
# 41698  ['http://dx.doi.org/10.7717/peerj.453', '(scik...   ['scikit-image']
# 60373                                               None               None

# %% [markdown]
# <a id='dataset_interaction_linked_metadata_fields'></a>
# #### Exploration of metadata fields
#
# In this section, we want to offer some examples of the type of metadata we are able to retrieve through the links we created. <br>
# First, let's remind ourselves the fields we have available:

# %%
linked_df.columns
# Out:
# Index(['ID', 'software_mention', 'mapped_to', 'source', 'platform',
#        'package_url', 'description', 'homepage_url', 'other_urls', 'license',
#        'github_repo', 'github_repo_license', 'exact_match', 'RRID',
#        'reference', 'scicrunch_synonyms'],
#       dtype='object')

# %% [markdown]
# And here is a full description of the metadata fields:
#
# | field | description |
# | :--- | :--- |
# | **ID** 	| unique ID of software mention (generated by us) |
# | **software_mention**	| plain-text software mention |
# | **mapped_to**	| value the software_mention is being mapped to |
# | **source**	| source of the mapping - eg Bioconductor Index, GitHub API |
# | **platform**	| platform of software_mention - eg PyPI, CRAN |
# | **package_url**	| URL linking software_mention to source |
# | **description**	| description of software_mention |
# | **homepage_url**	| homepage_url of software_mention |
# | **other_urls**	| other related URLs |
# | **license**	| software license |
# | **github_repo**	| GitHub repository |
# | **github_repo_license**	| GitHub repository license |
# | **exact_match**	| whether or not this mapping was an exact match |
# | **RRID**	| RRID for software_mention |
# | **reference**	| journal articles linked to software_mention (identified either through DOI, pmid or RRID) |
# | **scicrunch_synonyms**	| synonyms for software_mention, retrieved from Scicrunch |

# %%
pd.set_option('max_colwidth', 1000)

# %% [markdown]
# ##### package_url + description
# Examples for the software entities:

# %%
linked_df[linked_df['software_mention'] == software][['software_mention', 'package_url', 'description']]
# Out:
#       software_mention                                        package_url  \
# 41114   GraphPad Prism  https://scicrunch.org/browse/resources/SCR_002798
#
#                                                                                                                                                                                                                                                                                                                               description
# 41114  Statistical analysis software that combines scientific graphing, comprehensive curve fitting (nonlinear regression), understandable statistics, and data organization. Designed for biological research applications in pharmacology, physiology, and other biological fields for data analysis, hypothesis testing, and modeling.

# %% [markdown]
# ##### homepage_url + other_urls
# Examples for the software entities:

# %%
linked_df[linked_df['software_mention'] == software][['software_mention', 'homepage_url', 'other_urls']]
# Out:
#       software_mention                  homepage_url  \
# 41114   GraphPad Prism  ['http://www.graphpad.com/']
#
#                                                                                                                   other_urls
# 41114  ['http://graphpad-prism.software.informer.com/5.0/,', 'https://www.graphpad.com/guides/prism/7/user-guide/index.htm']

# %% [markdown]
# ##### github_repo + github_repo_license
# Examples for the software entities:

# %%
linked_df[linked_df['software_mention'] == 'scipy'][['software_mention', 'github_repo', 'github_repo_license']]
# Out:
#       software_mention                         github_repo github_repo_license
# 7908             scipy  ['https://github.com/scipy/scipy']                 NaN
# 41700            scipy                              [None]                 NaN
# 60375            scipy      https://github.com/scipy/scipy                 NaN

# %% [markdown]
# ##### RRID
# Examples for the software entities:

# %%
linked_df[linked_df['software_mention'] == software][['software_mention', 'RRID']]
# Out:
#       software_mention        RRID
# 41114   GraphPad Prism  SCR_002798

# %% [markdown]
# ##### reference
# Examples for the software entities:

# %%
linked_df[linked_df['software_mention'] == 'ImageJ'][['software_mention', 'reference']]
# Out:
#       software_mention  \
# 41105           ImageJ
#
#                                                                                     reference
# 41105  ['http://www.ncbi.nlm.nih.gov/pubmed/29187165, 22930834', '(ImageJ, RRID:SCR_003070)']

# %% [markdown]
# ##### scicrunch_synonyms
# Examples for the software entities:

# %%
linked_df[linked_df['software_mention'] == 'BLAST'][['software_mention', 'scicrunch_synonyms']]
# Out:
#       software_mention                    scicrunch_synonyms
# 41167            BLAST  ['blast similarity search', 'blast']

# %% [markdown]
# ##### platform
# Examples for the software entities:

# %%
linked_df[linked_df['software_mention'] == 'scipy'][['software_mention', 'platform']]
# Out:
#       software_mention platform
# 7908             scipy     Pypi
# 41700            scipy      NaN
# 60375            scipy      NaN

# %% [markdown]
# ##### license
# Examples for the software entities:

# %%
linked_df[linked_df['software_mention'] == 'scipy'][['software_mention', 'license']]
# Out:
#       software_mention                      license
# 7908             scipy  OSI Approved :: BSD License
# 41700            scipy                          NaN
# 60375            scipy                          NaN

# %% [markdown]
# <a id='dataset_interaction_linked_query'></a>
# ## Query the dataset for a particular software, retrieving all the data
# In this section, we offer an example of querying the dataset end2end for a particular software entitiy, retrieving all of the available information <br>
# Let's take for example the software_mention **scikit-learn**

# %% [markdown]
# ###### 1. Retrieve software entity mapping

# %%
software_mention = 'sklearn'
mention_df = disambiguated_df[disambiguated_df['software'] == software_mention]

# %%
software_mention_mapping = disambiguated_df[disambiguated_df['software'] == software_mention]['mapped_to_software'].values[0]
print('Mapped', software_mention, 'to', software_mention_mapping)
# Out:
# Mapped sklearn to scikit-learn

# %% [markdown]
# ###### 2. Retrieve string variations

# %%
string_variations = disambiguated_df[disambiguated_df['mapped_to_software'] == software_mention_mapping]['software'].unique()
print('String variations for', software_mention_mapping)
print('=' * 30)
print(string_variations)
# Out:
# String variations for scikit-learn
# ==============================
# ['Scikit-Learn' 'scikit-learn Python' 'scikit-learn' 'Scikit learn'
#  'sklearn' 'scikit-learn Python library' 'Scikit-learn' 'Sklearn'
#  'Python scikit-learn' 'scikit learn' 'scikit‐learn' 'Scikit‐learn'
#  'Scikit-Learn Python' 'scikit-learn81' 'SciKit-Learn' 'sklearn Python'
#  'Python package scikit-learn' 'Scikit-learn Python library'
#  'Scikit Learn5' 'Scikit-learn Python package' 'Sci-Kit Learn'
#  'Python Scikit-learn' 'Scikit Learn' 'scikit-learn Python package'
#  'Python Scikit-learn library' 'Sci-kit Learn'
#  'Python scikit-learn package' 'sci-kit learn' 'Scikit Learn Python'
#  'SciKit Learn' 'scikit-learn2' 'Python scikit-learn library'
#  'Sci-kit learn' 'Scikit-learn Python' 'Python Sklearn library'
#  'Sklearn Python' 'Scikit-learn29' 'scikits-learn' 'Python Sklearn'
#  'sci-kit-learn' 'scikit_learn' 'SciKit-learn Python library' 'SkLearn'
#  'scikit -learn' 'Python Scikit-Learn' 'Python3 sklearn' 'SciKitLearn'
#  'scikitlearn' 'ScikitLearn' 'SciKit-learn' 'Python package sci-kit learn'
#  'Python Scikit-learn package' 'Scikit-learn python library'
#  'Python3 sklearn library' 'Scikit-Learn Python library'
#  'scikit-learn python' 'sci-kitlearn' 'SCIKIT-LEARN'
#  'sklearn Python package' 'Scikit-learn Python Library' 'Python sklearn'
#  'Scikit‐Learn' 'scikit-learn python package'
#  'Scikit-learn python package' 'Python package scikit learn'
#  'Python sci-kit-learn' 'Scikit–learn' 'scikit.learn Python'
#  'Python-sklearn' 'Python Scikit-Learn library' 'Scikits-Learn'
#  'SCiKit-learn' 'SciKit learn' 'Scikit-Learn24' 'Python SciKit-learn'
#  'scikit-learn33' 'SKLEARN' 'Scikit-Learn®' 'Python sklearn library'
#  'scikit.learn' 'Scikits-learn' 'Sci-kit-learn'
#  'scikit-learn Python3 package' 'Sci-Kit learn' 'sklearn0'
#  'Python Scikit Learn' 'Scikit-Learn Python Library' 'Python scikit_learn'
#  '2scikit-learn' 'SCikit-learn' 'SCIKIT-learn' 'Scikit–Learn'
#  'Python Sci-kit learn' 'Python package Scikit-learn' 'scikit-learn8'
#  'scikit-Learn' 'Scikit-Learn Python package' 'scikit-learn10'
#  'Scikitlearn' 'Scikit_learn' 'scikit-learn python library'
#  'scikit - learn' 'Python sklearn-library' 'scikit-learn48'
#  'Scikit-learn31' 'scikit-learn Python package2223' 'scikit-learn22'
#  'Sci-Kit Learn Python library' 'Python3 scikit-learn' 'Scikit-learn:'
#  'Python Scikit Learn package' 'Scikit-learn0'
#  'scikit-learn Python Library' 'sklearn python package'
#  'sci-kit learn Python package' 'Python scikit learn package' 'skLearn'
#  'Scikit-learn python' 'scikitslearn' 'scikit-learn Python package for'
#  'Python sci-kit learn' 'Scikit–Learn Python'
#  'scikit - learn Python library' 'Sci-Kit Learn Python Library']

# %% [markdown]
# ###### 3. Retrieve total number of unique publications mention appears in

# %% [markdown]
# ###### undisambiguated

# %%
num_counts_undisambiguated = disambiguated_df[disambiguated_df['software'] == software_mention]['pmid'].nunique()
print(software_mention, 'appears in', num_counts_undisambiguated, 'number of PMIDs')
# Out:
# sklearn appears in 556 number of PMIDs

# %% [markdown]
# ###### disambiguated

# %%
num_counts_disambiguated = disambiguated_df[disambiguated_df['software'] == software_mention_mapping]['pmid'].nunique()
print(software_mention, 'is mapped to', software_mention_mapping, 'which appears in', num_counts_disambiguated, 'number of PMIDs')
# Out:
# sklearn is mapped to scikit-learn which appears in 2415 number of PMIDs

# %% [markdown]
# ###### 4. Retrieve metadata

# %%
software_mention_medatada = linked_df[linked_df['software_mention'] == software_mention]

# %%
software_mention_medatada
# Out:
#            ID software_mention mapped_to         source platform  \
# 8276   SM3414          sklearn   sklearn     Pypi Index     Pypi
# 41751  SM3414          sklearn   Sklearn  SciCrunch API      NaN
# 60459  SM3414          sklearn   sklearn     Github API      NaN
#
#                                              package_url  \
# 8276                    https://pypi.org/project/sklearn
# 41751  https://scicrunch.org/browse/resources/SCR_019053
# 60459              https://github.com/KeithGalli/sklearn
#
#                                                                                                                                                                                                                                                                                                                                  description  \
# 8276                                                                                                                                                                                                                                                                            A set of python modules for machine learning and data mining
# 41751  Software Python package part of nonnegative matrix factorization NMF. Features various classification, regression and clustering algorithms including support vector machines, random forests, gradient boosting, k-means and DBSCAN, and is designed to interoperate with Python numerical and scientific libraries NumPy and SciPy.
# 60459                                                                                                                                                                                                                                        Data & Code associated with my tutorial on the sci-kit learn machine learning library in python
#
#                                                                                homepage_url  \
# 8276                                         ['https://pypi.python.org/pypi/scikit-learn/']
# 41751  ['https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.NMF.html']
# 60459                                                                                   NaN
#
#                                                                                   other_urls  \
# 8276                                                                                     NaN
# 41751  ['https://github.com/scikit-learn/scikit-learn,', 'https://scikit-learn.org/stable/']
# 60459                                                                                    NaN
#
#       license                                        github_repo  \
# 8276      NaN                                             [None]
# 41751     NaN  ['https://github.com/scikit-learn/scikit-learn,']
# 60459     NaN              https://github.com/KeithGalli/sklearn
#
#       github_repo_license exact_match        RRID  \
# 8276                  NaN        True        None
# 41751                 NaN       False  SCR_019053
# 60459                 NaN        True        None
#
#                                  reference scicrunch_synonyms
# 8276                                  None               None
# 41751  [nan, '(Sklearn, RRID:SCR_019053)']        ['sklearn']
# 60459                                 None               None

# %% [markdown]
# <a id='prompts'></a>
#
# That's it! This notebook serves as a starting point for showcasing how particular research questions might be answered using the data available in the **CZI Software Mentions Dataset**. It is our hope that it sparks further analyses and interesting research directions. <br>
#
# **A non-exhaustive list potential questions to consider next is:**
# 1. Understanding the context in which a software mention appears. Ideas include using topic modeling, pretrained language models embeddings or models for citation intent classification.
# 2. Drawing better insights about usage of software in particular fields by incorporating other metadata about a paper, such as  MESH terms, author provided-keywords, title, or abstract
# 3. Explore measure of impact for software, such as Eigenfactor
# 4. Looking into open-access policies of most used or impactful software, and how that varies in particular fields
# 5. Exploring differences in how software usage varies over time
#
#
# We are excited about the work that will build on top of the **CZI Software Mentions Dataset** and can't wait to see what other ideas you come up with!

# %% [markdown]
# ### References
#
# <a id='references_scibert'>1. Beltagy, Iz, Kyle Lo, and Arman Cohan. "SciBERT: A pretrained language model for scientific text." arXiv preprint arXiv:1903.10676 (2019).</a> <br>
# <a id='references_dbscan'>2. Ester, Martin, et al. "A density-based algorithm for discovering clusters in large spatial databases with noise." kdd. Vol. 96. No. 34. 1996.</a>
